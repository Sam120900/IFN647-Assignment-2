# %%
import os

def load_top_10_results(results_file):
    top_10_rank = {}
    with open(results_file) as f:
        for i in range(1, 11):
            line = f.readline().strip()
            if not line:
                break
            lineList = line.split()
            # Strip '.xml' extension from document IDs
            doc_id = lineList[0].replace('.xml', '')
            top_10_rank[str(i)] = doc_id
    return top_10_rank

def save_top_10_results(top_10_data, output_file):
    with open(output_file, 'w') as f:
        for rank, doc_id in top_10_data.items():
            f.write(f"{rank}\t{doc_id}\n")

def process_top_10_results(query_range, models, results_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for model_name, results_pattern in models.items():
        for query_id in query_range:
            results_file = results_pattern.format(query_id=query_id)
            if os.path.exists(results_file):
                top_10_data = load_top_10_results(results_file)
                output_file = os.path.join(output_folder, f"{model_name}_R{query_id}_Top10.dat")
                save_top_10_results(top_10_data, output_file)
                print(f"Top 10 results for Query {query_id} ({model_name}) saved to {output_file}")
            else:
                print(f"Results file for Query {query_id} ({model_name}) does not exist.")

# Define the query range and models
query_range = range(101, 151)  # Adjust range as needed
results_folder = "RankingOutputs"
output_folder = "Top10Results"
models = {
    "BM25": os.path.join(results_folder, "BM25_R{query_id}Ranking.dat"),
    "JM_LM": os.path.join(results_folder, "JM_LM_R{query_id}Ranking.dat"),
    "MY_PRM": os.path.join(results_folder, "My_PRM_R{query_id}Ranking.dat"),
}

# Process and save top 10 results
process_top_10_results(query_range, models, results_folder, output_folder)
# Out:
# Top 10 results for Query 101 (BM25) saved to Top10Results/BM25_R101_Top10.dat
# Top 10 results for Query 102 (BM25) saved to Top10Results/BM25_R102_Top10.dat
# Top 10 results for Query 103 (BM25) saved to Top10Results/BM25_R103_Top10.dat
# Top 10 results for Query 104 (BM25) saved to Top10Results/BM25_R104_Top10.dat
# Top 10 results for Query 105 (BM25) saved to Top10Results/BM25_R105_Top10.dat
# Top 10 results for Query 106 (BM25) saved to Top10Results/BM25_R106_Top10.dat
# Top 10 results for Query 107 (BM25) saved to Top10Results/BM25_R107_Top10.dat
# Top 10 results for Query 108 (BM25) saved to Top10Results/BM25_R108_Top10.dat
# Top 10 results for Query 109 (BM25) saved to Top10Results/BM25_R109_Top10.dat
# Top 10 results for Query 110 (BM25) saved to Top10Results/BM25_R110_Top10.dat
# Top 10 results for Query 111 (BM25) saved to Top10Results/BM25_R111_Top10.dat
# Top 10 results for Query 112 (BM25) saved to Top10Results/BM25_R112_Top10.dat
# Top 10 results for Query 113 (BM25) saved to Top10Results/BM25_R113_Top10.dat
# Top 10 results for Query 114 (BM25) saved to Top10Results/BM25_R114_Top10.dat
# Top 10 results for Query 115 (BM25) saved to Top10Results/BM25_R115_Top10.dat
# Top 10 results for Query 116 (BM25) saved to Top10Results/BM25_R116_Top10.dat
# Top 10 results for Query 117 (BM25) saved to Top10Results/BM25_R117_Top10.dat
# Top 10 results for Query 118 (BM25) saved to Top10Results/BM25_R118_Top10.dat
# Top 10 results for Query 119 (BM25) saved to Top10Results/BM25_R119_Top10.dat
# Top 10 results for Query 120 (BM25) saved to Top10Results/BM25_R120_Top10.dat
# Top 10 results for Query 121 (BM25) saved to Top10Results/BM25_R121_Top10.dat
# Top 10 results for Query 122 (BM25) saved to Top10Results/BM25_R122_Top10.dat
# Top 10 results for Query 123 (BM25) saved to Top10Results/BM25_R123_Top10.dat
# Top 10 results for Query 124 (BM25) saved to Top10Results/BM25_R124_Top10.dat
# Top 10 results for Query 125 (BM25) saved to Top10Results/BM25_R125_Top10.dat
# Top 10 results for Query 126 (BM25) saved to Top10Results/BM25_R126_Top10.dat
# Top 10 results for Query 127 (BM25) saved to Top10Results/BM25_R127_Top10.dat
# Top 10 results for Query 128 (BM25) saved to Top10Results/BM25_R128_Top10.dat
# Top 10 results for Query 129 (BM25) saved to Top10Results/BM25_R129_Top10.dat
# Top 10 results for Query 130 (BM25) saved to Top10Results/BM25_R130_Top10.dat
# Top 10 results for Query 131 (BM25) saved to Top10Results/BM25_R131_Top10.dat
# Top 10 results for Query 132 (BM25) saved to Top10Results/BM25_R132_Top10.dat
# Top 10 results for Query 133 (BM25) saved to Top10Results/BM25_R133_Top10.dat
# Top 10 results for Query 134 (BM25) saved to Top10Results/BM25_R134_Top10.dat
# Top 10 results for Query 135 (BM25) saved to Top10Results/BM25_R135_Top10.dat
# Top 10 results for Query 136 (BM25) saved to Top10Results/BM25_R136_Top10.dat
# Top 10 results for Query 137 (BM25) saved to Top10Results/BM25_R137_Top10.dat
# Top 10 results for Query 138 (BM25) saved to Top10Results/BM25_R138_Top10.dat
# Top 10 results for Query 139 (BM25) saved to Top10Results/BM25_R139_Top10.dat
# Top 10 results for Query 140 (BM25) saved to Top10Results/BM25_R140_Top10.dat
# Top 10 results for Query 141 (BM25) saved to Top10Results/BM25_R141_Top10.dat
# Top 10 results for Query 142 (BM25) saved to Top10Results/BM25_R142_Top10.dat
# Top 10 results for Query 143 (BM25) saved to Top10Results/BM25_R143_Top10.dat
# Top 10 results for Query 144 (BM25) saved to Top10Results/BM25_R144_Top10.dat
# Top 10 results for Query 145 (BM25) saved to Top10Results/BM25_R145_Top10.dat
# Top 10 results for Query 146 (BM25) saved to Top10Results/BM25_R146_Top10.dat
# Top 10 results for Query 147 (BM25) saved to Top10Results/BM25_R147_Top10.dat
# Top 10 results for Query 148 (BM25) saved to Top10Results/BM25_R148_Top10.dat
# Top 10 results for Query 149 (BM25) saved to Top10Results/BM25_R149_Top10.dat
# Top 10 results for Query 150 (BM25) saved to Top10Results/BM25_R150_Top10.dat
# Top 10 results for Query 101 (JM_LM) saved to Top10Results/JM_LM_R101_Top10.dat
# Top 10 results for Query 102 (JM_LM) saved to Top10Results/JM_LM_R102_Top10.dat
# Top 10 results for Query 103 (JM_LM) saved to Top10Results/JM_LM_R103_Top10.dat
# Top 10 results for Query 104 (JM_LM) saved to Top10Results/JM_LM_R104_Top10.dat
# Top 10 results for Query 105 (JM_LM) saved to Top10Results/JM_LM_R105_Top10.dat
# Top 10 results for Query 106 (JM_LM) saved to Top10Results/JM_LM_R106_Top10.dat
# Top 10 results for Query 107 (JM_LM) saved to Top10Results/JM_LM_R107_Top10.dat
# Top 10 results for Query 108 (JM_LM) saved to Top10Results/JM_LM_R108_Top10.dat
# Top 10 results for Query 109 (JM_LM) saved to Top10Results/JM_LM_R109_Top10.dat
# Top 10 results for Query 110 (JM_LM) saved to Top10Results/JM_LM_R110_Top10.dat
# Top 10 results for Query 111 (JM_LM) saved to Top10Results/JM_LM_R111_Top10.dat
# Top 10 results for Query 112 (JM_LM) saved to Top10Results/JM_LM_R112_Top10.dat
# Top 10 results for Query 113 (JM_LM) saved to Top10Results/JM_LM_R113_Top10.dat
# Top 10 results for Query 114 (JM_LM) saved to Top10Results/JM_LM_R114_Top10.dat
# Top 10 results for Query 115 (JM_LM) saved to Top10Results/JM_LM_R115_Top10.dat
# Top 10 results for Query 116 (JM_LM) saved to Top10Results/JM_LM_R116_Top10.dat
# Top 10 results for Query 117 (JM_LM) saved to Top10Results/JM_LM_R117_Top10.dat
# Top 10 results for Query 118 (JM_LM) saved to Top10Results/JM_LM_R118_Top10.dat
# Top 10 results for Query 119 (JM_LM) saved to Top10Results/JM_LM_R119_Top10.dat
# Top 10 results for Query 120 (JM_LM) saved to Top10Results/JM_LM_R120_Top10.dat
# Top 10 results for Query 121 (JM_LM) saved to Top10Results/JM_LM_R121_Top10.dat
# Top 10 results for Query 122 (JM_LM) saved to Top10Results/JM_LM_R122_Top10.dat
# Top 10 results for Query 123 (JM_LM) saved to Top10Results/JM_LM_R123_Top10.dat
# Top 10 results for Query 124 (JM_LM) saved to Top10Results/JM_LM_R124_Top10.dat
# Top 10 results for Query 125 (JM_LM) saved to Top10Results/JM_LM_R125_Top10.dat
# Top 10 results for Query 126 (JM_LM) saved to Top10Results/JM_LM_R126_Top10.dat
# Top 10 results for Query 127 (JM_LM) saved to Top10Results/JM_LM_R127_Top10.dat
# Top 10 results for Query 128 (JM_LM) saved to Top10Results/JM_LM_R128_Top10.dat
# Top 10 results for Query 129 (JM_LM) saved to Top10Results/JM_LM_R129_Top10.dat
# Top 10 results for Query 130 (JM_LM) saved to Top10Results/JM_LM_R130_Top10.dat
# Top 10 results for Query 131 (JM_LM) saved to Top10Results/JM_LM_R131_Top10.dat
# Top 10 results for Query 132 (JM_LM) saved to Top10Results/JM_LM_R132_Top10.dat
# Top 10 results for Query 133 (JM_LM) saved to Top10Results/JM_LM_R133_Top10.dat
# Top 10 results for Query 134 (JM_LM) saved to Top10Results/JM_LM_R134_Top10.dat
# Top 10 results for Query 135 (JM_LM) saved to Top10Results/JM_LM_R135_Top10.dat
# Top 10 results for Query 136 (JM_LM) saved to Top10Results/JM_LM_R136_Top10.dat
# Top 10 results for Query 137 (JM_LM) saved to Top10Results/JM_LM_R137_Top10.dat
# Top 10 results for Query 138 (JM_LM) saved to Top10Results/JM_LM_R138_Top10.dat
# Top 10 results for Query 139 (JM_LM) saved to Top10Results/JM_LM_R139_Top10.dat
# Top 10 results for Query 140 (JM_LM) saved to Top10Results/JM_LM_R140_Top10.dat
# Top 10 results for Query 141 (JM_LM) saved to Top10Results/JM_LM_R141_Top10.dat
# Top 10 results for Query 142 (JM_LM) saved to Top10Results/JM_LM_R142_Top10.dat
# Top 10 results for Query 143 (JM_LM) saved to Top10Results/JM_LM_R143_Top10.dat
# Top 10 results for Query 144 (JM_LM) saved to Top10Results/JM_LM_R144_Top10.dat
# Top 10 results for Query 145 (JM_LM) saved to Top10Results/JM_LM_R145_Top10.dat
# Top 10 results for Query 146 (JM_LM) saved to Top10Results/JM_LM_R146_Top10.dat
# Top 10 results for Query 147 (JM_LM) saved to Top10Results/JM_LM_R147_Top10.dat
# Top 10 results for Query 148 (JM_LM) saved to Top10Results/JM_LM_R148_Top10.dat
# Top 10 results for Query 149 (JM_LM) saved to Top10Results/JM_LM_R149_Top10.dat
# Top 10 results for Query 150 (JM_LM) saved to Top10Results/JM_LM_R150_Top10.dat
# Top 10 results for Query 101 (MY_PRM) saved to Top10Results/MY_PRM_R101_Top10.dat
# Top 10 results for Query 102 (MY_PRM) saved to Top10Results/MY_PRM_R102_Top10.dat
# Top 10 results for Query 103 (MY_PRM) saved to Top10Results/MY_PRM_R103_Top10.dat
# Top 10 results for Query 104 (MY_PRM) saved to Top10Results/MY_PRM_R104_Top10.dat
# Top 10 results for Query 105 (MY_PRM) saved to Top10Results/MY_PRM_R105_Top10.dat
# Top 10 results for Query 106 (MY_PRM) saved to Top10Results/MY_PRM_R106_Top10.dat
# Top 10 results for Query 107 (MY_PRM) saved to Top10Results/MY_PRM_R107_Top10.dat
# Top 10 results for Query 108 (MY_PRM) saved to Top10Results/MY_PRM_R108_Top10.dat
# Top 10 results for Query 109 (MY_PRM) saved to Top10Results/MY_PRM_R109_Top10.dat
# Top 10 results for Query 110 (MY_PRM) saved to Top10Results/MY_PRM_R110_Top10.dat
# Top 10 results for Query 111 (MY_PRM) saved to Top10Results/MY_PRM_R111_Top10.dat
# Top 10 results for Query 112 (MY_PRM) saved to Top10Results/MY_PRM_R112_Top10.dat
# Top 10 results for Query 113 (MY_PRM) saved to Top10Results/MY_PRM_R113_Top10.dat
# Top 10 results for Query 114 (MY_PRM) saved to Top10Results/MY_PRM_R114_Top10.dat
# Top 10 results for Query 115 (MY_PRM) saved to Top10Results/MY_PRM_R115_Top10.dat
# Top 10 results for Query 116 (MY_PRM) saved to Top10Results/MY_PRM_R116_Top10.dat
# Top 10 results for Query 117 (MY_PRM) saved to Top10Results/MY_PRM_R117_Top10.dat
# Top 10 results for Query 118 (MY_PRM) saved to Top10Results/MY_PRM_R118_Top10.dat
# Top 10 results for Query 119 (MY_PRM) saved to Top10Results/MY_PRM_R119_Top10.dat
# Top 10 results for Query 120 (MY_PRM) saved to Top10Results/MY_PRM_R120_Top10.dat
# Top 10 results for Query 121 (MY_PRM) saved to Top10Results/MY_PRM_R121_Top10.dat
# Top 10 results for Query 122 (MY_PRM) saved to Top10Results/MY_PRM_R122_Top10.dat
# Top 10 results for Query 123 (MY_PRM) saved to Top10Results/MY_PRM_R123_Top10.dat
# Top 10 results for Query 124 (MY_PRM) saved to Top10Results/MY_PRM_R124_Top10.dat
# Top 10 results for Query 125 (MY_PRM) saved to Top10Results/MY_PRM_R125_Top10.dat
# Top 10 results for Query 126 (MY_PRM) saved to Top10Results/MY_PRM_R126_Top10.dat
# Top 10 results for Query 127 (MY_PRM) saved to Top10Results/MY_PRM_R127_Top10.dat
# Top 10 results for Query 128 (MY_PRM) saved to Top10Results/MY_PRM_R128_Top10.dat
# Top 10 results for Query 129 (MY_PRM) saved to Top10Results/MY_PRM_R129_Top10.dat
# Top 10 results for Query 130 (MY_PRM) saved to Top10Results/MY_PRM_R130_Top10.dat
# Top 10 results for Query 131 (MY_PRM) saved to Top10Results/MY_PRM_R131_Top10.dat
# Top 10 results for Query 132 (MY_PRM) saved to Top10Results/MY_PRM_R132_Top10.dat
# Top 10 results for Query 133 (MY_PRM) saved to Top10Results/MY_PRM_R133_Top10.dat
# Top 10 results for Query 134 (MY_PRM) saved to Top10Results/MY_PRM_R134_Top10.dat
# Top 10 results for Query 135 (MY_PRM) saved to Top10Results/MY_PRM_R135_Top10.dat
# Top 10 results for Query 136 (MY_PRM) saved to Top10Results/MY_PRM_R136_Top10.dat
# Top 10 results for Query 137 (MY_PRM) saved to Top10Results/MY_PRM_R137_Top10.dat
# Top 10 results for Query 138 (MY_PRM) saved to Top10Results/MY_PRM_R138_Top10.dat
# Top 10 results for Query 139 (MY_PRM) saved to Top10Results/MY_PRM_R139_Top10.dat
# Top 10 results for Query 140 (MY_PRM) saved to Top10Results/MY_PRM_R140_Top10.dat
# Top 10 results for Query 141 (MY_PRM) saved to Top10Results/MY_PRM_R141_Top10.dat
# Top 10 results for Query 142 (MY_PRM) saved to Top10Results/MY_PRM_R142_Top10.dat
# Top 10 results for Query 143 (MY_PRM) saved to Top10Results/MY_PRM_R143_Top10.dat
# Top 10 results for Query 144 (MY_PRM) saved to Top10Results/MY_PRM_R144_Top10.dat
# Top 10 results for Query 145 (MY_PRM) saved to Top10Results/MY_PRM_R145_Top10.dat
# Top 10 results for Query 146 (MY_PRM) saved to Top10Results/MY_PRM_R146_Top10.dat
# Top 10 results for Query 147 (MY_PRM) saved to Top10Results/MY_PRM_R147_Top10.dat
# Top 10 results for Query 148 (MY_PRM) saved to Top10Results/MY_PRM_R148_Top10.dat
# Top 10 results for Query 149 (MY_PRM) saved to Top10Results/MY_PRM_R149_Top10.dat
# Top 10 results for Query 150 (MY_PRM) saved to Top10Results/MY_PRM_R150_Top10.dat
